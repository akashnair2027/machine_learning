# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %%
df = pd.read_csv('Tokyo Medals 2021.csv')

# %%
df.head()
# Out:
#                       Country  Gold Medal  Silver Medal  Bronze Medal  Total  \
# 0    United States of America          39            41            33    113
# 1  People's Republic of China          38            32            18     88
# 2                       Japan          27            14            17     58
# 3               Great Britain          22            21            22     65
# 4                         ROC          20            28            23     71
#
#    Rank By Total
# 0              1
# 1              2
# 2              5
# 3              4
# 4              3

# %%
df.tail()
# Out:
#                  Country  Gold Medal  Silver Medal  Bronze Medal  Total  \
# 88                 Ghana           0             0             1      1
# 89               Grenada           0             0             1      1
# 90                Kuwait           0             0             1      1
# 91   Republic of Moldova           0             0             1      1
# 92  Syrian Arab Republic           0             0             1      1
#
#     Rank By Total
# 88             77
# 89             77
# 90             77
# 91             77
# 92             77

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 93 entries, 0 to 92
# Data columns (total 6 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   Country        93 non-null     object
#  1   Gold Medal     93 non-null     int64
#  2   Silver Medal   93 non-null     int64
#  3   Bronze Medal   93 non-null     int64
#  4   Total          93 non-null     int64
#  5   Rank By Total  93 non-null     int64
# dtypes: int64(5), object(1)
# memory usage: 4.5+ KB

# %%
df.describe()
# Out:
#        Gold Medal  Silver Medal  Bronze Medal       Total  Rank By Total
# count   93.000000     93.000000     93.000000   93.000000      93.000000
# mean     3.655914      3.634409      4.322581   11.612903      43.494624
# std      7.022471      6.626339      6.210372   19.091332      24.171769
# min      0.000000      0.000000      0.000000    1.000000       1.000000
# 25%      0.000000      0.000000      1.000000    2.000000      23.000000
# 50%      1.000000      1.000000      2.000000    4.000000      47.000000
# 75%      3.000000      4.000000      5.000000   11.000000      66.000000
# max     39.000000     41.000000     33.000000  113.000000      77.000000

# %%
df.shape
# Out:
# (93, 6)

# %%
df.isnull().sum()
# Out:
# Country          0
# Gold Medal       0
# Silver Medal     0
# Bronze Medal     0
# Total            0
# Rank By Total    0
# dtype: int64

# %%
df.corr()
# Out:
#                Gold Medal  Silver Medal  Bronze Medal     Total  Rank By Total
# Gold Medal       1.000000      0.929046      0.862425  0.970840      -0.626012
# Silver Medal     0.929046      1.000000      0.862646  0.969439      -0.632831
# Bronze Medal     0.862425      0.862646      1.000000  0.941941      -0.745573
# Total            0.970840      0.969439      0.941941  1.000000      -0.692450
# Rank By Total   -0.626012     -0.632831     -0.745573 -0.692450       1.000000

# %%
df
# Out:
#                        Country  Gold  Silver  Bronze  Total  World_rank
# 0     United States of America    39      41      33    113           1
# 1   People's Republic of China    38      32      18     88           2
# 2                        Japan    27      14      17     58           5
# 3                Great Britain    22      21      22     65           4
# 4                          ROC    20      28      23     71           3
# ..                         ...   ...     ...     ...    ...         ...
# 88                       Ghana     0       0       1      1          77
# 89                     Grenada     0       0       1      1          77
# 90                      Kuwait     0       0       1      1          77
# 91         Republic of Moldova     0       0       1      1          77
# 92        Syrian Arab Republic     0       0       1      1          77
#
# [93 rows x 6 columns]

# %%
# rename 
df.rename(columns= {"Gold Medal":"Gold","Silver Medal":"Silver","Bronze Medal":"Bronze","Rank By Total":"World_rank"},inplace = True)

# %%
df.sort_values(by=["World_rank"],ascending =True,inplace= True)
df.head(10)
# Out:
#                       Country  Gold  Silver  Bronze  Total  World_rank
# 0    United States of America    39      41      33    113           1
# 1  People's Republic of China    38      32      18     88           2
# 4                         ROC    20      28      23     71           3
# 3               Great Britain    22      21      22     65           4
# 2                       Japan    27      14      17     58           5
# 5                   Australia    17       7      22     46           6
# 9                       Italy    10      10      20     40           7
# 8                     Germany    10      11      16     37           8
# 6                 Netherlands    10      12      14     36           9
# 7                      France    10      12      11     33          10

# %%
df.sort_values(by=["Gold","Country"],ascending=True,inplace=True)

# %%
df.query('Country == "India"')
# Out:
# Empty DataFrame
# Columns: [Country, Gold, Silver, Bronze, Total, World_rank]
# Index: []

# %%
v =pd.DataFrame(df.World_rank =="India").count()
v
# Out:
# World_rank    93
# dtype: int64

# %%
sns.pairplot(data=df)

# %%
plt.xlabel('')
plt.bar(df.Gold,df.Country)
# Out:
# <BarContainer object of 93 artists>
